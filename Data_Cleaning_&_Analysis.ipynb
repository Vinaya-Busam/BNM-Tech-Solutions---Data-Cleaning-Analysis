# %% [markdown]
# <a href="https://colab.research.google.com/github/Vinaya-Busam/BNM-Tech-Solutions---Data-Cleaning-Analysis/blob/main/Data_Cleaning_%26_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Load & Understand the Dataset

# %%
dataset = pd.read_csv("/content/netflix_titles.csv")

# %%
print("First 5 rows:\n")
dataset.head()
# Out:
# First 5 rows:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
print("Last 5 rows:\n")
dataset.tail()
# Out:
# Last 5 rows:
#      show_id     type        title         director  \
# 8802   s8803    Movie       Zodiac    David Fincher
# 8803   s8804  TV Show  Zombie Dumb              NaN
# 8804   s8805    Movie   Zombieland  Ruben Fleischer
# 8805   s8806    Movie         Zoom     Peter Hewitt
# 8806   s8807    Movie       Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                                NaN            NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#              date_added  release_year rating   duration  \
# 8802  November 20, 2019          2007      R    158 min
# 8803       July 1, 2019          2018  TV-Y7  2 Seasons
# ...

# %%
print("Shape of dataset:", dataset.shape)
# Out:
# Shape of dataset: (8807, 12)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %% [markdown]
# ## Handling Missing Values

# %% [markdown]
# #### Cheking missing values

# %%
dataset.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %% [markdown]
# #### Filling missing values

# %%
dataset['director'].fillna('Unknown', inplace=True)
dataset['cast'].fillna('Unknown', inplace=True)
dataset['country'].fillna('Unknown', inplace=True)

dataset['rating'].fillna(dataset['rating'].mode()[0], inplace=True)
# Out:
# /tmp/ipykernel_10609/544989440.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataset['director'].fillna('Unknown', inplace=True)
# /tmp/ipykernel_10609/544989440.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
dataset.dropna(subset=['date_added', 'duration'], inplace=True)

# %%
dataset.isnull().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# description     0
# dtype: int64

# %%
dataset.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water          Unknown
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans          Unknown
# 4      s5  TV Show           Kota Factory          Unknown
#
#                                                 cast        country  \
# 0                                            Unknown  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...        Unknown
# 3                                            Unknown        Unknown
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
print("Shape of dataset after handling missing values:")
dataset.shape
# Out:
# Shape of dataset after handling missing values:
# (8794, 12)

# %% [markdown]
# # Remove Duplicate Records

# %%
duplicates = dataset.duplicated().sum()
print("Duplicated Rows:", duplicates)
# Out:
# Duplicated Rows: 0

# %% [markdown]
# There are no duplicated records

# %% [markdown]
# # Data Cleaning & Preprocessing

# %% [markdown]
# #### Convert Date Column

# %%
dataset['date_added'] = pd.to_datetime(dataset['date_added'], format='mixed')

# %%
dataset.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water          Unknown
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans          Unknown
# 4      s5  TV Show           Kota Factory          Unknown
#
#                                                 cast        country  \
# 0                                            Unknown  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...        Unknown
# 3                                            Unknown        Unknown
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#   date_added  release_year rating   duration  \
# 0 2021-09-25          2020  PG-13     90 min
# 1 2021-09-24          2021  TV-MA  2 Seasons
# 2 2021-09-24          2021  TV-MA   1 Season
# ...

# %% [markdown]
# #### Extract Year Added

# %%
dataset['year_added'] = dataset['date_added'].dt.year

# %% [markdown]
# #### Clean duration column

# %%
dataset['duration_num'] = dataset['duration'].str.extract(r'(\d+)')
dataset['duration_num'] = pd.to_numeric(dataset['duration_num'])

# %%
dataset.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water          Unknown
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans          Unknown
# 4      s5  TV Show           Kota Factory          Unknown
#
#                                                 cast        country  \
# 0                                            Unknown  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...        Unknown
# 3                                            Unknown        Unknown
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#   date_added  release_year rating   duration  \
# 0 2021-09-25          2020  PG-13     90 min
# 1 2021-09-24          2021  TV-MA  2 Seasons
# 2 2021-09-24          2021  TV-MA   1 Season
# ...

# %% [markdown]
# #### Remove Extra Spaces

# %%
dataset['country'] = dataset['country'].str.strip()
dataset['director'] = dataset['director'].str.strip()

# %%
dataset.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water          Unknown
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans          Unknown
# 4      s5  TV Show           Kota Factory          Unknown
#
#                                                 cast        country  \
# 0                                            Unknown  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...        Unknown
# 3                                            Unknown        Unknown
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#   date_added  release_year rating   duration  \
# 0 2021-09-25          2020  PG-13     90 min
# 1 2021-09-24          2021  TV-MA  2 Seasons
# 2 2021-09-24          2021  TV-MA   1 Season
# ...

# %% [markdown]
# # Summary Statistics

# %%
print(dataset.describe())
# Out:
#                           date_added  release_year  duration_num   year_added
# count                           8794   8794.000000   8794.000000  8794.000000
# mean   2019-05-17 13:29:44.034568960   2014.183534     69.920173  2018.872754
# min              2008-01-01 00:00:00   1925.000000      1.000000  2008.000000
# 25%              2018-04-06 00:00:00   2013.000000      2.000000  2018.000000
# 50%              2019-07-02 00:00:00   2017.000000     88.000000  2019.000000
# 75%              2020-08-19 00:00:00   2019.000000    106.000000  2020.000000
# max              2021-09-25 00:00:00   2021.000000    312.000000  2021.000000
# std                              NaN      8.823527     50.797005     1.573789

# %% [markdown]
# **Movies vs TV Shows Count**

# %%
print(dataset['type'].value_counts())
# Out:
# type
# Movie      6128
# TV Show    2666
# Name: count, dtype: int64

# %% [markdown]
# **Content Ratings**

# %%
print(dataset['rating'].value_counts())
# Out:
# rating
# TV-MA       3209
# TV-14       2157
# TV-PG        861
# R            799
# PG-13        490
# TV-Y7        333
# TV-Y         306
# PG           287
# TV-G         220
# NR            79
# G             41
# TV-Y7-FV       6
# NC-17          3
# UR             3
# Name: count, dtype: int64

# %% [markdown]
# **Top Countries**

# %%
print(dataset['country'].value_counts().head(10))
# Out:
# country
# United States     2809
# India              972
# Unknown            830
# United Kingdom     418
# Japan              244
# South Korea        199
# Canada             181
# Spain              145
# France             124
# Mexico             110
# Name: count, dtype: int64

# %% [markdown]
# **Top Genres**

# %%
print(dataset['listed_in'].value_counts().head(10))
# Out:
# listed_in
# Dramas, International Movies                        362
# Documentaries                                       359
# Stand-Up Comedy                                     334
# Comedies, Dramas, International Movies              274
# Dramas, Independent Movies, International Movies    252
# Kids' TV                                            219
# Children & Family Movies                            215
# Children & Family Movies, Comedies                  201
# Documentaries, International Movies                 186
# Dramas, International Movies, Romantic Movies       180
# Name: count, dtype: int64

# %% [markdown]
# # Visualizations

# %% [markdown]
# **Movies vs TV Shows**

# %%
dataset['type'].value_counts().plot(kind='bar')
plt.title('Movies vs TV Shows')
plt.show()

# %% [markdown]
# **Content Added Over Time**

# %%
dataset['year_added'].value_counts().sort_index().plot(kind='line')
plt.title('Netflix Content Added Per Year')
plt.show()

# %% [markdown]
# **Top 10 Countries**

# %%
dataset['country'].value_counts().head(10).plot(kind='pie')
plt.title('Top 10 Content Producing Countries')
plt.show()

# %% [markdown]
# **Ratings Distribution**

# %%
dataset['rating'].value_counts().plot(kind='bar')
plt.title('Ratings Distribution')
plt.show()

# %% [markdown]
# # Insights

# %% [markdown]
# #### 1. Movies dominate Netflix content

# %%
sns.countplot(x='type', color='k', data=dataset)
plt.title('Movies vs TV Shows')
plt.show()

# %% [markdown]
# #### 2. Netflix expanded rapidly after 2015

# %%
content_by_year = dataset['year_added'].value_counts().sort_index()

content_by_year.plot(kind='line', marker='o', color='k')
plt.title('Content Added to Netflix Over Time')
plt.xlabel('Year')
plt.ylabel('Number of Titles')
plt.show()

# %% [markdown]
# #### Movie Duration Distribution

# %%
movies = dataset[dataset['type'] == 'Movie']

sns.histplot(movies['duration_num'], bins=20)
plt.title('Movie Duration Distribution')
plt.xlabel('Minutes')
plt.show()
